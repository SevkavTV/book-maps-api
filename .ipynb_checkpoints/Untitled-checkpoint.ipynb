# %%
import pandas as pd

# %%
df = pd.read_csv('classification.csv')
df
# Out:
#       Dewey classification  BL record ID            Type of resource  \
# 0                 4.600000      16115497                   Monograph
# 1                 5.000000       9136348                   Monograph
# 2                70.449951      15118285                   Monograph
# 3               100.000000       9814404                   Monograph
# 4               100.000000      12353971                   Monograph
# ...                    ...           ...                         ...
# 1196            949.501300       6526555  Monographic component part
# 1197            949.502000      10113446                   Monograph
# 1198            951.024000      16315320                   Monograph
# 1199            951.930000       7416697                   Monograph
# 1200            951.930000       9166542                   Monograph
#
#                   Content type    Material type BNB number  \
# 0     Language material ; Text  Online resource        NaN
# ...

# %%
pd = pd['Type of resource'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-87c722323e9c> in <module>
# ----> 1 pd = pd['Type of resource'].value_counts()
#
# TypeError: 'module' object is not subscriptable

# %%
df['Content type'].value_counts()
# Out:
# Language material ; Text                                           737
# Language material ; Still image ; Text                             287
# Notated music                                                      163
# Language material ; Spoken word ; Still image ; Text                 5
# Language material                                                    3
# Language material ; Spoken word ; Text                               3
# Language material ; Still image ; Text ; Three-dimensional form      2
# Language material ; Text ; Three-dimensional form                    1
# Name: Content type, dtype: int64

# %%
df = df[df['Content type'] == 'Language material ; Still image ; Text']
df['Title']
# df[['Country of publication', 'Place of creation/publication']]
# Out:
# 57                      A is for Alice : an alphabet book
# 58                      A is for Alice : an alphabet book
# 59            Alice's alphabet book : a Wonderland A to Z
# 73                                    Alice in Wonderland
# 74                       Alice's adventures in Wonderland
#                               ...
# 1185    Alice's Oxford on foot : Lewis Carroll's Alice...
# 1188    Greek perspectives on the Achaemenid Empire : ...
# 1189    Greek perspectives on the Achaemenid Empire : ...
# 1190    Greek perspectives on the Achaemenid Empire : ...
# 1192                                Rayleigh through time
# Name: Title, Length: 287, dtype: object

# %%
df['Type of resource'].value_counts()
# Out:
# Monograph    287
# Name: Type of resource, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('classification.csv')
df['ISBN'].value_counts()
# df = df[df['ISBN'] == '9780850889970']
# df['Title']
# Out:
# 9781898248040                    3
# 9780192816207                    2
# 9780582534148                    2
# 9780815764359 ; 9780815764366    2
# 9780813333090 ; 9780813333106    2
#                                 ..
# 9780140624083                    1
# 9780008127879                    1
# 9780746076590                    1
# 9780905935225                    1
# 9780950084510                    1
# Name: ISBN, Length: 933, dtype: int64

# %%
from database import DatabaseConfig, Database
db = Database(DatabaseConfig)
db.find_books_by_param('Anturiaethau Alys yng Ngwlad Hud')
# Out:
# [nan, '9781904808466', '9780850889970']

# %%
from database import DatabaseConfig, Database
db = Database(DatabaseConfig)
db.data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1076 entries, 0 to 1075
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Content type                   1076 non-null   object
#  1   Material type                  1073 non-null   object
#  2   ISBN                           904 non-null    object
#  3   Name                           966 non-null    object
#  4   Dates associated with name     622 non-null    object
#  5   Role                           677 non-null    object
#  6   All names                      1057 non-null   object
#  7   Title                          1076 non-null   object
#  8   Variant titles                 519 non-null    object
#  9   Series title                   291 non-null    object
#  10  Country of publication         1076 non-null   object
#  11  Place of creation/publication  1076 non-null   object
# ...

# %%
from database import DatabaseConfig, Database
db = Database(DatabaseConfig)
db.find_books_by_param('California')
# Out:
# ['9781888375954',
#  '9780980104400 ; 9780980104417',
#  '9780811875585',
#  '9781597961141',
#  '9781597961233',
#  '9780520048201',
#  '9781613779132',
#  '9781597961134',
#  '9780916990046',
#  '9781600105968',
#  '9780764587214',
#  '9781427837776',
#  '9781234567897 ; 9781387594566',
#  '9781597961127']

# %%
from database import DatabaseConfig, Database
db = Database(DatabaseConfig)
db.get_book_info('9780930326258')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 899    False
# 900    False
# 901    False
# 902    False
# 903    False
# Name: ISBN, Length: 904, dtype: bool
